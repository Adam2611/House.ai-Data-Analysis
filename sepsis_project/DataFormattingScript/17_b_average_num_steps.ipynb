# %%
#this file calaculatas average number of time steps

# %%
import pandas as pd
#import modin.pandas as pd

# %%
df1 = pd.read_csv(
     '../FormattedData/34.csv'
)

# %%
df1
# Out:
#          Unnamed: 0  new_date    BP1   BP2  Pulse  Temp    RR  O2Sat  \
# 0                 0       0.0  126.0  93.0  115.0  36.2  18.0   98.0
# 1                 1      30.0    NaN   NaN  111.0   NaN   NaN  100.0
# 2                 2     269.0  127.0  98.0   85.0   NaN  18.0    NaN
# 3                 3    1222.0  113.0  80.0   62.0  36.5   NaN    NaN
# 4                 4    1695.0  102.0  64.0   69.0   NaN   NaN    NaN
# ...             ...       ...    ...   ...    ...   ...   ...    ...
# 1080969     1080969  398544.0  115.0  40.0   67.0   NaN  16.0  100.0
# 1080970     1080970  398621.0  122.0  59.0   72.0   NaN  16.0   95.0
# 1080971     1080971  398711.0  120.0  78.0   77.0  36.7  16.0   95.0
# 1080972     1080972  398997.0  157.0  82.0   64.0  36.5  15.0   94.0
# 1080973     1080973  399290.0  147.0  82.0   63.0  36.6  16.0   96.0
#
#          Age_Number Gender
# 0                46      M
# 1                46      M
# 2                46      M
# ...

# %%
del df1["Unnamed: 0"]

# %%
df1.head(30)
# Out:
#     new_date    BP1   BP2  Pulse  Temp    RR  O2Sat  Age_Number Gender
# 0        0.0  126.0  93.0  115.0  36.2  18.0   98.0          46      M
# 1       30.0    NaN   NaN  111.0   NaN   NaN  100.0          46      M
# 2      269.0  127.0  98.0   85.0   NaN  18.0    NaN          46      M
# 3     1222.0  113.0  80.0   62.0  36.5   NaN    NaN          46      M
# 4     1695.0  102.0  64.0   69.0   NaN   NaN    NaN          46      M
# 5     3259.0  121.0  65.0  104.0  36.5   NaN  100.0          46      M
# 6    11184.0  127.0  83.0  113.0  37.2  16.0   97.0          46      M
# 7   103997.0  130.0  92.0   93.0  36.8  14.0  100.0          46      M
# 8   168976.0  143.0  97.0  123.0  36.6  14.0  100.0          46      M
# 9   169317.0  125.0  96.0   86.0  36.7  18.0   98.0          46      M
# 10  169648.0    NaN   NaN   66.0  36.5  16.0  100.0          46      M
# 11  328220.0  152.0  82.0   70.0   NaN  18.0   98.0          46      M
# ...

# %%
rows = len(df1)
rows
# Out:
# 1080974

# %%
df1.iloc[2][1] #row, column
# Out:
# 127.0

# %%
i = 1
times = []
count = 0
zeroes = 0

while i<rows:
    time = df1.iloc[i][0]
    if time != 0:
        count+=1
    else:
        zeroes +=1
        times.append(count+1)
        count=0

    i+=1

# %%
average = sum(times)/len(times)

# %%
average
#is the average number of steps
# Out:
# 78.40414883585987

# %%
zeroes
#is the number of new time samples
# Out:
# 13787
