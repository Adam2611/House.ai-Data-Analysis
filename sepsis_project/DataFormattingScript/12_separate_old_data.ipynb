# %%
#this file looks at the time and separates them if the value is over 10,000 minutes away (1 week)

# %%
import pandas as pd

# %%
df1 = pd.read_csv(
     '../FormattedData/37.csv'
)

# %%
df1
# Out:
#          Unnamed: 0  new_date    BP1   BP2  Pulse  Temp    RR  O2Sat  \
# 0                 0       0.0  126.0  93.0  115.0  36.2  18.0   98.0
# 1                 1      30.0   -1.0  -1.0  111.0  -1.0  -1.0  100.0
# 2                 2     269.0  127.0  98.0   85.0  -1.0  18.0   -1.0
# 3                 3    1222.0  113.0  80.0   62.0  36.5  -1.0   -1.0
# 4                 4    1695.0  102.0  64.0   69.0  -1.0  -1.0   -1.0
# ...             ...       ...    ...   ...    ...   ...   ...    ...
# 1080969     1080969  398544.0  115.0  40.0   67.0  -1.0  16.0  100.0
# 1080970     1080970  398621.0  122.0  59.0   72.0  -1.0  16.0   95.0
# 1080971     1080971  398711.0  120.0  78.0   77.0  36.7  16.0   95.0
# 1080972     1080972  398997.0  157.0  82.0   64.0  36.5  15.0   94.0
# 1080973     1080973  399290.0  147.0  82.0   63.0  36.6  16.0   96.0
#
#          Age_Number  Male  Female
# 0                46     1       0
# 1                46     1       0
# ...

# %%
del df1["Unnamed: 0"]

# %%
df1
# Out:
#          new_date    BP1   BP2  Pulse  Temp    RR  O2Sat  Age_Number  Male  \
# 0             0.0  126.0  93.0  115.0  36.2  18.0   98.0          46     1
# 1            30.0   -1.0  -1.0  111.0  -1.0  -1.0  100.0          46     1
# 2           269.0  127.0  98.0   85.0  -1.0  18.0   -1.0          46     1
# 3          1222.0  113.0  80.0   62.0  36.5  -1.0   -1.0          46     1
# 4          1695.0  102.0  64.0   69.0  -1.0  -1.0   -1.0          46     1
# ...           ...    ...   ...    ...   ...   ...    ...         ...   ...
# 1080969  398544.0  115.0  40.0   67.0  -1.0  16.0  100.0          63     1
# 1080970  398621.0  122.0  59.0   72.0  -1.0  16.0   95.0          63     1
# 1080971  398711.0  120.0  78.0   77.0  36.7  16.0   95.0          63     1
# 1080972  398997.0  157.0  82.0   64.0  36.5  15.0   94.0          63     1
# 1080973  399290.0  147.0  82.0   63.0  36.6  16.0   96.0          63     1
#
#          Female
# 0             0
# 1             0
# ...

# %%
rows = len(df1)
rows
# Out:
# 1080974

# %%
print (df1.iloc[0][1])
# Out:
# 126.0

# %%
i=1
date_list = []
date_list.append(df1.iloc[0][0])
days = 3
time_threshold = days*1440
while i<rows-2:
    value1 = df1.iloc[i][0]
    value0 = df1.iloc[i-1][0] 

    if (value1-value0) > time_threshold:
        subtracted = df1.iloc[i][0]
        date_list.append(0.0)
        new_idx = i+1

        while new_idx<rows and df1.iloc[new_idx][0] != 0.0 and (df1.iloc[new_idx][0]-df1.iloc[new_idx-1][0])<time_threshold:
            changed_v = df1.iloc[new_idx][0]
            date_list.append(changed_v - subtracted)
            new_idx += 1
            i += 1
    else:
        date_list.append(value1)
    

    i+=1

# %%
date_list[0:50]
# Out:
# [0.0,
#  30.0,
#  269.0,
#  1222.0,
#  1695.0,
#  3259.0,
#  0.0,
#  0.0,
#  0.0,
#  341.0,
#  672.0,
#  0.0,
#  400.0,
#  1099.0,
#  1269.0,
#  0.0,
#  0.0,
#  115.0,
#  166.0,
#  284.0,
#  486.0,
#  664.0,
#  931.0,
#  1045.0,
#  1281.0,
#  1536.0,
#  1653.0,
#  1898.0,
#  2371.0,
#  3140.0,
#  3782.0,
#  4522.0,
#  5231.0,
#  5641.0,
#  5753.0,
#  0.0,
#  0.0,
#  24.0,
#  43.0,
#  72.0,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  422.0,
#  912.0,
#  972.0,
#  1215.0,
#  1292.0,
#  1663.0]

# %%
del df1["new_date"]
df1["new_date"] = date_list

# %%
df1 = df1[['new_date', 'BP1', 'BP2', 'Pulse', 'Temp', 'RR', 'O2Sat',
       'Age_Number', 'Male', 'Female']]

# %%
df1
# Out:
#          new_date    BP1   BP2  Pulse  Temp    RR  O2Sat  Age_Number  Male  \
# 0             0.0  126.0  93.0  115.0  36.2  18.0   98.0          46     1
# 1            30.0   -1.0  -1.0  111.0  -1.0  -1.0  100.0          46     1
# 2           269.0  127.0  98.0   85.0  -1.0  18.0   -1.0          46     1
# 3          1222.0  113.0  80.0   62.0  36.5  -1.0   -1.0          46     1
# 4          1695.0  102.0  64.0   69.0  -1.0  -1.0   -1.0          46     1
# ...           ...    ...   ...    ...   ...   ...    ...         ...   ...
# 1080969     855.0  115.0  40.0   67.0  -1.0  16.0  100.0          63     1
# 1080970     932.0  122.0  59.0   72.0  -1.0  16.0   95.0          63     1
# 1080971    1022.0  120.0  78.0   77.0  36.7  16.0   95.0          63     1
# 1080972    1308.0  157.0  82.0   64.0  36.5  15.0   94.0          63     1
# 1080973    1601.0  147.0  82.0   63.0  36.6  16.0   96.0          63     1
#
#          Female
# 0             0
# 1             0
# ...

# %%
df1.head(50)
# Out:
#     new_date    BP1    BP2  Pulse  Temp    RR  O2Sat  Age_Number  Male  Female
# 0        0.0  126.0   93.0  115.0  36.2  18.0   98.0          46     1       0
# 1       30.0   -1.0   -1.0  111.0  -1.0  -1.0  100.0          46     1       0
# 2      269.0  127.0   98.0   85.0  -1.0  18.0   -1.0          46     1       0
# 3     1222.0  113.0   80.0   62.0  36.5  -1.0   -1.0          46     1       0
# 4     1695.0  102.0   64.0   69.0  -1.0  -1.0   -1.0          46     1       0
# 5     3259.0  121.0   65.0  104.0  36.5  -1.0  100.0          46     1       0
# 6        0.0  127.0   83.0  113.0  37.2  16.0   97.0          46     1       0
# 7        0.0  130.0   92.0   93.0  36.8  14.0  100.0          46     1       0
# 8        0.0  143.0   97.0  123.0  36.6  14.0  100.0          46     1       0
# 9      341.0  125.0   96.0   86.0  36.7  18.0   98.0          46     1       0
# 10     672.0   -1.0   -1.0   66.0  36.5  16.0  100.0          46     1       0
# ...

# %%
df1.to_csv('38.csv')
