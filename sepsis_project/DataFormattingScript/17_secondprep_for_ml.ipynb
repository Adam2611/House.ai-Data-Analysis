# %%
#this file deletes the first 3 categories and flags no lab values as -1

# %%
import pandas as pd
#import modin.pandas as pd

# %%
df1 = pd.read_csv(
     '../FormattedData/17a_deleted_outliers_manually.csv'
)

# %%
df1
# Out:
#         Unnamed: 0 pt_identifier  positive_diag  negative_diag  new_date  BP1  \
# 0                0      H1000412              0              1         0  125
# 1                1      H1000412              0              1        23   -1
# 2                2      H1000412              0              1       450  138
# 3                3      H1000412              0              1       467   -1
# 4                4      H1000412              0              1       531  116
# ...            ...           ...            ...            ...       ...  ...
# 308890      308890       Z991743              0              1      4209  153
# 308891      308891       Z991743              0              1      4219   -1
# 308892      308892       Z991743              0              1      4947  152
# 308893      308893       Z991743              0              1      5661  174
# 308894      308894       Z992617              0              1         0   -1
#
# ...

# %%
del df1["Unnamed: 0"]

# %%
df1.head(10)
# Out:
#   pt_identifier  positive_diag  negative_diag  new_date  BP1  BP2  Pulse  \
# 0      H1000412              0              1         0  125   79     96
# 1      H1000412              0              1        23   -1   -1     -1
# 2      H1000412              0              1       450  138   76     98
# 3      H1000412              0              1       467   -1   -1     -1
# 4      H1000412              0              1       531  116   84     88
# 5      H1000412              0              1       763  126   64     69
# 6      H1000412              0              1       929   -1   -1     -1
# 7      H1002797              0              1         0  166   90     58
# 8      H1002797              0              1       166   -1   -1     -1
# 9      H1002797              0              1       168   -1   -1     -1
#
#    Temp  RR  O2Sat  Age_Number  Male  Female  Lactate_adjusted  WBC_adjusted
# 0  37.4  13     96          81     0       1          0.000000      0.000000
# ...

# %%
rows = len(df1)
rows
# Out:
# 308895

# %%
del df1["pt_identifier"]
del df1["positive_diag"]
del df1["negative_diag"]

# %%
df1
# Out:
#         new_date  BP1  BP2  Pulse  Temp  RR  O2Sat  Age_Number  Male  Female  \
# 0              0  125   79     96  37.4  13     96          81     0       1
# 1             23   -1   -1     -1  -1.0  -1     -1          81     0       1
# 2            450  138   76     98  36.8  16     98          81     0       1
# 3            467   -1   -1     -1  -1.0  -1     -1          81     0       1
# 4            531  116   84     88  36.9  17     97          81     0       1
# ...          ...  ...  ...    ...   ...  ..    ...         ...   ...     ...
# 308890      4209  153   64     58  36.5  16     96          92     0       1
# 308891      4219   -1   -1     -1  -1.0  -1     -1          92     0       1
# 308892      4947  152   65     63  36.6  18     94          92     0       1
# 308893      5661  174   70     69  36.7  16     92          92     0       1
# 308894         0   -1   -1     -1  -1.0  -1     -1          -1     0       0
#
#         Lactate_adjusted  WBC_adjusted
# ...

# %%
df1.loc[df1['Lactate_adjusted'] == 0.0, 'Lactate_adjusted'] = -1

# %%
df1
# Out:
#         new_date  BP1  BP2  Pulse  Temp  RR  O2Sat  Age_Number  Male  Female  \
# 0              0  125   79     96  37.4  13     96          81     0       1
# 1             23   -1   -1     -1  -1.0  -1     -1          81     0       1
# 2            450  138   76     98  36.8  16     98          81     0       1
# 3            467   -1   -1     -1  -1.0  -1     -1          81     0       1
# 4            531  116   84     88  36.9  17     97          81     0       1
# ...          ...  ...  ...    ...   ...  ..    ...         ...   ...     ...
# 308890      4209  153   64     58  36.5  16     96          92     0       1
# 308891      4219   -1   -1     -1  -1.0  -1     -1          92     0       1
# 308892      4947  152   65     63  36.6  18     94          92     0       1
# 308893      5661  174   70     69  36.7  16     92          92     0       1
# 308894         0   -1   -1     -1  -1.0  -1     -1          -1     0       0
#
#         Lactate_adjusted  WBC_adjusted
# ...

# %%
df1.loc[df1['WBC_adjusted'] == 0.0, 'WBC_adjusted'] = -1

# %%
df1
# Out:
#         new_date  BP1  BP2  Pulse  Temp  RR  O2Sat  Age_Number  Male  Female  \
# 0              0  125   79     96  37.4  13     96          81     0       1
# 1             23   -1   -1     -1  -1.0  -1     -1          81     0       1
# 2            450  138   76     98  36.8  16     98          81     0       1
# 3            467   -1   -1     -1  -1.0  -1     -1          81     0       1
# 4            531  116   84     88  36.9  17     97          81     0       1
# ...          ...  ...  ...    ...   ...  ..    ...         ...   ...     ...
# 308890      4209  153   64     58  36.5  16     96          92     0       1
# 308891      4219   -1   -1     -1  -1.0  -1     -1          92     0       1
# 308892      4947  152   65     63  36.6  18     94          92     0       1
# 308893      5661  174   70     69  36.7  16     92          92     0       1
# 308894         0   -1   -1     -1  -1.0  -1     -1          -1     0       0
#
#         Lactate_adjusted  WBC_adjusted
# ...

# %%
df1.to_csv('../FormattedData/pre_ml_2.csv')
