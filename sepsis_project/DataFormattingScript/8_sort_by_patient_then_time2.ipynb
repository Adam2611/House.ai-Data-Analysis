# %%
# this file sorts again by patient and then by time

# %%
import pandas as pd

# %%
df1 = pd.read_csv(
     '../FormattedData/32.csv',
)

# %%
df1 = df1.rename(columns={'Date': 'new_date'})

# %%
df1.head(50)
# Out:
#     Unnamed: 0 pt_identifier  new_date    BP1    BP2  Pulse  Temp    RR  \
# 0            0      H1000105  328620.0  106.0   70.0   78.0   NaN  16.0
# 1            1      H1000105  730234.0  118.0   79.0   99.0   NaN  18.0
# 2            2      H1000105  730205.0  107.0   74.0   98.0   NaN  20.0
# 3            3      H1000105  730186.0  104.0   63.0   94.0   NaN  10.0
# 4            4      H1000105  469347.0  109.0   75.0   84.0  36.4  20.0
# 5            5      H1000105  469111.0   90.0   71.0   66.0  36.8  16.0
# 6            6      H1000105  468997.0   95.0   60.0   70.0  36.4  20.0
# 7            7      H1000105  468730.0   99.0   60.0   56.0   NaN  16.0
# 8            8      H1000105  468552.0   90.0   60.0   62.0   NaN  16.0
# 9            9      H1000105  471206.0  133.0   88.0   87.0  36.3  16.0
# 10          10      H1000105  468350.0   96.0   63.0   78.0  36.8  16.0
# 11          11      H1000105  468181.0   91.0   57.0   86.0  36.8  20.0
# ...

# %%
del df1["Unnamed: 0"]

# %%
df2 = df1.sort_values(['pt_identifier', 'new_date'], ascending=[True, True])

# %%
df2.head(50)
# Out:
#    pt_identifier  new_date    BP1    BP2  Pulse  Temp    RR  O2Sat  \
# 23      H1000105       0.0  126.0   93.0  115.0  36.2  18.0   98.0
# 32      H1000105      30.0    NaN    NaN  111.0   NaN   NaN  100.0
# 38      H1000105     269.0  127.0   98.0   85.0   NaN  18.0    NaN
# 37      H1000105    1222.0  113.0   80.0   62.0  36.5   NaN    NaN
# 36      H1000105    1695.0  102.0   64.0   69.0   NaN   NaN    NaN
# 35      H1000105    3259.0  121.0   65.0  104.0  36.5   NaN  100.0
# 26      H1000105   11184.0  127.0   83.0  113.0  37.2  16.0   97.0
# 30      H1000105  103997.0  130.0   92.0   93.0  36.8  14.0  100.0
# 25      H1000105  168976.0  143.0   97.0  123.0  36.6  14.0  100.0
# 33      H1000105  169317.0  125.0   96.0   86.0  36.7  18.0   98.0
# 14      H1000105  169648.0    NaN    NaN   66.0  36.5  16.0  100.0
# 24      H1000105  328220.0  152.0   82.0   70.0   NaN  18.0   98.0
# 0       H1000105  328620.0  106.0   70.0   78.0   NaN  16.0   96.0
# ...

# %%
df2.to_csv('../FormattedData/33.csv')#vitals_info_lactate_WBC_normalized_time_sorted_pt_and_time_stage3

# %%
df2
# Out:
#         pt_identifier  new_date    BP1   BP2  Pulse  Temp    RR  O2Sat  \
# 23           H1000105       0.0  126.0  93.0  115.0  36.2  18.0   98.0
# 32           H1000105      30.0    NaN   NaN  111.0   NaN   NaN  100.0
# 38           H1000105     269.0  127.0  98.0   85.0   NaN  18.0    NaN
# 37           H1000105    1222.0  113.0  80.0   62.0  36.5   NaN    NaN
# 36           H1000105    1695.0  102.0  64.0   69.0   NaN   NaN    NaN
# ...               ...       ...    ...   ...    ...   ...   ...    ...
# 1080964       Z999621  398544.0  115.0  40.0   67.0   NaN  16.0  100.0
# 1080963       Z999621  398621.0  122.0  59.0   72.0   NaN  16.0   95.0
# 1080960       Z999621  398711.0  120.0  78.0   77.0  36.7  16.0   95.0
# 1080959       Z999621  398997.0  157.0  82.0   64.0  36.5  15.0   94.0
# 1080961       Z999621  399290.0  147.0  82.0   63.0  36.6  16.0   96.0
#
#          Age_Number Gender
# 23               46      M
# 32               46      M
# 38               46      M
# ...
